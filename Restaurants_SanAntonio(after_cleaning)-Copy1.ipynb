# %% [markdown]
# # Restaurants San Antonio

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn import metrics
from sklearn.metrics import precision_recall_fscore_support
import matplotlib.pyplot as plt


# File to Load
file_path = Path("Restaurants_SanAntonio.csv")

# Read Restaurant Data File and store into Pandas DataFrame
restaurants_df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
restaurants_df.head()
# Out:
#       id  position                                             name  score  \
# 0  34517         6                                 Fiesta Liquor #3    3.0
# 1  34518         5                              Squeezers Juice Bar    5.0
# 2  34520        76           Spinster Sisters Co. (427 Lombrano St)    NaN
# 3  34521       194                               Yaya's Thai Fusion    NaN
# 4  34522       192  Willie's Grill &amp; Icehouse (7911 Interstate)    4.5
#
#    ratings                                           category price_range  \
# 0      NaN  African, Ethiopian, Vegetarian, Alcohol, Liquo...           $
# 1     11.0  Black-owned, Juice and Smoothies, African, Hea...         NaN
# 2      NaN  Home &amp; Personal Care, Everyday Essentials,...           $
# 3      NaN                               Thai, Asian, Noodles           $
# 4     92.0  American, Burgers, Family Friendly, Wings, Alc...           $
#
#          lat        lng                       address          city state  \
# 0  29.574320 -98.515210             14415 Blanco Road   San Antonio    TX
# 1  29.441000 -98.485470        914 East Elmira Street   San Antonio    TX
# 2  29.441910 -98.510550               427 Lombrano St   San Antonio    TX
# 3  29.480652 -98.607908       5819 Northwest Loop 410   San Antonio    TX
# 4  29.350066 -98.537672  7911 Interstate 35 Access Rd   San Antonio    TX
#
#    zip_code
# 0   78248.0
# 1   78212.0
# 2   78207.0
# 3   78238.0
# 4   78224.0

# %%
restaurants_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1215 entries, 0 to 1214
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           1215 non-null   int64
#  1   position     1215 non-null   int64
#  2   name         1215 non-null   object
#  3   score        672 non-null    float64
#  4   ratings      671 non-null    float64
#  5   category     1214 non-null   object
#  6   price_range  955 non-null    object
#  7   lat          1215 non-null   float64
#  8   lng          1215 non-null   float64
#  9   address      1215 non-null   object
#  10  city         1215 non-null   object
#  11  state        1215 non-null   object
#  12  zip_code     1214 non-null   float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 123.5+ KB

# %%
# Check which columns have NaN values and how many NaN values are present in each column
nan_counts = restaurants_df.isnull().sum()

# Display the count of NaN values in each column
print(nan_counts)
# Out:
# id               0
# position         0
# name             0
# score          543
# ratings        544
# category         1
# price_range    260
# lat              0
# lng              0
# address          0
# city             0
# state            0
# zip_code         1
# dtype: int64

# %%
# Removing rows with NaN values and storing the result in a new DataFrame
restaurants_df_cleaned = restaurants_df.dropna()

# Display the first few rows of the cleaned DataFrame
restaurants_df_cleaned.head()
# Out:
#        id  position                                               name  score  \
# 4   34522       192    Willie's Grill &amp; Icehouse (7911 Interstate)    4.5
# 8   34527       190                McDonald's® (1643 Pleasanton Road)    4.2
# 25  34547       215  The Philly Cheesesteak Company (1011 N Loop 16...    3.9
# 28  34551       171  Zito's Delicatessen &amp; Sandwich Shop (8800 ...    4.8
# 29  34552       160                Nachos Muchachos (427 Lombrano St,)    3.2
#
#     ratings                                           category price_range  \
# 4      92.0  American, Burgers, Family Friendly, Wings, Alc...           $
# 8     167.0                       American, Fast Food, Burgers           $
# 25     41.0                     American, Sandwiches, Desserts           $
# 28     11.0                      Sandwiches, American, Healthy          $$
# 29     33.0                          American, Mexican, Snacks          $$
#
#           lat        lng                       address          city state  \
# 4   29.350066 -98.537672  7911 Interstate 35 Access Rd   San Antonio    TX
# 8   29.366126 -98.504588            1643 Pleasanton Rd   San Antonio    TX
# 25  29.611140 -98.477810            1011 N Loop 1604 E   San Antonio    TX
# 28  29.520260 -98.460730              8800 Broadway St   San Antonio    TX
# 29  29.441910 -98.510550               427 Lombrano St   San Antonio    TX
#
#     zip_code
# 4    78224.0
# 8    78221.0
# 25   78232.0
# 28   78217.0
# 29   78207.0

# %%
restaurants_df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 558 entries, 4 to 1214
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           558 non-null    int64
#  1   position     558 non-null    int64
#  2   name         558 non-null    object
#  3   score        558 non-null    float64
#  4   ratings      558 non-null    float64
#  5   category     558 non-null    object
#  6   price_range  558 non-null    object
#  7   lat          558 non-null    float64
#  8   lng          558 non-null    float64
#  9   address      558 non-null    object
#  10  city         558 non-null    object
#  11  state        558 non-null    object
#  12  zip_code     558 non-null    float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 61.0+ KB

# %%
#Saving the file
restaurants_df_cleaned.to_csv("Output/restaurants_df.csv", index=False, header=True)

# %% [markdown]
# ## Data Preparation

# %%
#Make a copy of the DF to edit for Linear Regression
clean_copy = restaurants_df_cleaned.copy()
clean_copy.head()
# Out:
#        id  position                                               name  score  \
# 4   34522       192    Willie's Grill &amp; Icehouse (7911 Interstate)    4.5
# 8   34527       190                McDonald's® (1643 Pleasanton Road)    4.2
# 25  34547       215  The Philly Cheesesteak Company (1011 N Loop 16...    3.9
# 28  34551       171  Zito's Delicatessen &amp; Sandwich Shop (8800 ...    4.8
# 29  34552       160                Nachos Muchachos (427 Lombrano St,)    3.2
#
#     ratings                                           category price_range  \
# 4      92.0  American, Burgers, Family Friendly, Wings, Alc...           $
# 8     167.0                       American, Fast Food, Burgers           $
# 25     41.0                     American, Sandwiches, Desserts           $
# 28     11.0                      Sandwiches, American, Healthy          $$
# 29     33.0                          American, Mexican, Snacks          $$
#
#           lat        lng                       address          city state  \
# 4   29.350066 -98.537672  7911 Interstate 35 Access Rd   San Antonio    TX
# 8   29.366126 -98.504588            1643 Pleasanton Rd   San Antonio    TX
# 25  29.611140 -98.477810            1011 N Loop 1604 E   San Antonio    TX
# 28  29.520260 -98.460730              8800 Broadway St   San Antonio    TX
# 29  29.441910 -98.510550               427 Lombrano St   San Antonio    TX
#
#     zip_code
# 4    78224.0
# 8    78221.0
# 25   78232.0
# 28   78217.0
# 29   78207.0

# %%
# position (Restaurant position in the search result)--keep
# score (Restaurant score)--going to drop this to predict it
# category (Restaurant category)--Maybe keep?? may mean we sacrifice clustering later on
# price_range (Restaurant price range - $ = Inexpensive, $$ = Moderately expensive, $$$ = Expensive, $$$$ = Very Expensive) - Source - stackoverflow
# zip_code (Zip code)--keep!

#drop uneccessary columns
clean_copy.drop(columns=['id','name','lat', 'lng', 'address', 'city', 'state'], inplace=True)
print(clean_copy)
# Out:
#       position  score  ratings  \
# 4          192    4.5     92.0
# 8          190    4.2    167.0
# 25         215    3.9     41.0
# 28         171    4.8     11.0
# 29         160    3.2     33.0
# ...        ...    ...      ...
# 1207       100    4.2     21.0
# 1208        92    4.8    117.0
# 1209        88    4.6     92.0
# 1211        33    4.7    162.0
# 1214       185    4.5    186.0
#
#                                                category price_range  zip_code
# 4     American, Burgers, Family Friendly, Wings, Alc...           $   78224.0
# 8                          American, Fast Food, Burgers           $   78221.0
# 25                       American, Sandwiches, Desserts           $   78232.0
# 28                        Sandwiches, American, Healthy          $$   78217.0
# 29                            American, Mexican, Snacks          $$   78207.0
# ...                                                 ...         ...       ...
# 1207                                          Fast Food           $   78204.0
# 1208                       American, Burgers, Fast Food           $   78232.0
# 1209  Mexican, Tex Mex, Breakfast and Brunch, Family...           $   78223.0
# 1211                      Burgers, American, Sandwiches           $   78232.0
# 1214  Fast Food, American, Family Meals, Family Frie...           $   78211.0
#
# [558 rows x 6 columns]

# %%
#look at the category column to see if there are consistent values
clean_copy['category'].value_counts()
# Out:
# Mexican, Latin American, New Mexican                             22
# Burgers, American, Sandwiches                                    17
# Mexican, Tex Mex, Breakfast and Brunch, Family Meals              7
# American, Burgers, Fast Food                                      6
# Breakfast and Brunch, American, Sandwiches                        5
#                                                                  ..
# American, Diner                                                   1
# Burgers, American, Sandwiches, Seafood, Bar Food, Cafe, Wings     1
# Mexican, American                                                 1
# American, Burgers, Comfort Food, Pasta, Sandwich                  1
# Sandwich, Deli                                                    1
# Name: category, Length: 390, dtype: int64

# %%
#Find out how many categories already include the main categories
#Mexican, Italian, American, Vegetarian, Asian, Breakfast/Brunch, <---come back to this if we have time

# %%
#check dtypes
clean_copy.dtypes
# Out:
# position         int64
# score          float64
# ratings        float64
# category        object
# price_range     object
# zip_code       float64
# dtype: object

# %%
clean_copy['score'].unique()
# Out:
# array([4.5, 4.2, 3.9, 4.8, 3.2, 4.6, 4.7, 4.4, 4.1, 3.3, 4.9, 5. , 4.3,
#        4. , 3.8, 3.6, 3.5, 2.9, 3.7, 3.1, 3.4])

# %%
import math
#round the 'score' column before converting it to int
clean_copy["score"] = clean_copy["score"].apply(math.ceil)

# %%
#convert 'zip_code' to integer
clean_copy['zip_code']=clean_copy['zip_code'].astype(int)

# Convert score to int
clean_copy['score']=clean_copy['score'].astype(int)

#convert 'rating' to integer
clean_copy['ratings']=clean_copy['ratings'].astype(int)

# %%
#Use get_dummies to convert categorical columns to numerical values
dummy_price = pd.get_dummies(clean_copy['price_range'])
dummy_zip = pd.get_dummies(clean_copy['zip_code'])
dummy_category = pd.get_dummies(clean_copy['category'])

# %%
# Joining the new DataFrame back to the original one
data = pd.concat([clean_copy, dummy_price, dummy_zip, dummy_category], axis=1)

# Dropping the original 'price_range', category and 'zip_code' columns
data = data.drop('price_range', axis=1)
data = data.drop('zip_code', axis=1)
data = data.drop('category', axis=1)
data.head()
# Out:
#     position  score  ratings  $  $$  $$$  75038  78201  78202  78203  ...  \
# 4        192      5       92  1   0    0      0      0      0      0  ...
# 8        190      5      167  1   0    0      0      0      0      0  ...
# 25       215      4       41  1   0    0      0      0      0      0  ...
# 28       171      5       11  0   1    0      0      0      0      0  ...
# 29       160      4       33  0   1    0      0      0      0      0  ...
#
#     Vietnamese, Noodles, Healthy, Asian, Bubble Tea, Family Meals  \
# 4                                                   0
# 8                                                   0
# 25                                                  0
# 28                                                  0
# 29                                                  0
#
#     Vietnamese, Noodles, Healthy, Thai, Vegetarian, Soup, Pho, Rice &amp; Curry, Bubble Tea, Desserts, Local Specialities, Vegetarian Friendly  \
# 4                                                   0
# 8                                                   0
# 25                                                  0
# 28                                                  0
# 29                                                  0
#
#     Vietnamese, Noodles, Healthy, Vegetarian, Vegetarian Friendly, Thai, Rice Dishes, Chinese, Pho  \
# 4                                                   0
# 8                                                   0
# 25                                                  0
# 28                                                  0
# 29                                                  0
#
#     Vietnamese, Sandwich, Family Meals  \
# 4                                    0
# 8                                    0
# 25                                   0
# 28                                   0
# 29                                   0
#
#     Wings, American, Fast Food, Family Meals, Burgers  \
# 4                                                   0
# 8                                                   0
# 25                                                  0
# 28                                                  0
# 29                                                  0
#
#     Wings, Chicken, American  pizza, Sandwich, Salads  \
# 4                          0                        0
# 8                          0                        0
# 25                         0                        0
# 28                         0                        0
# 29                         0                        0
#
#     wings, American, Burgers, Family Friendly  \
# 4                                           0
# 8                                           0
# 25                                          0
# 28                                          0
# 29                                          0
#
#     wings, American, Chicken, Family Friendly  wings, American, Comfort Food
# 4                                           0                              0
# 8                                           0                              0
# 25                                          0                              0
# 28                                          0                              0
# 29                                          0                              0
#
# [5 rows x 440 columns]

# %%
data.dtypes
# Out:
# position                                     int64
# score                                        int32
# ratings                                      int32
# $                                            uint8
# $$                                           uint8
#                                              ...
# Wings, Chicken, American                     uint8
# pizza, Sandwich, Salads                      uint8
# wings, American, Burgers, Family Friendly    uint8
# wings, American, Chicken, Family Friendly    uint8
# wings, American, Comfort Food                uint8
# Length: 440, dtype: object

# %% [markdown]
# ### Begin the Model to Train and Test

# %%
# Split our preprocessed data into our features and target arrays
X = data.drop('score', axis=1)
y = data['score']

# %%
# Review the y variable Series
y.head()
# Out:
# 4     5
# 8     5
# 25    4
# 28    5
# 29    4
# Name: score, dtype: int32

# %%
# Review the X variable DataFrame
X.head()
# Out:
#     position  ratings  $  $$  $$$  75038  78201  78202  78203  78204  ...  \
# 4        192       92  1   0    0      0      0      0      0      0  ...
# 8        190      167  1   0    0      0      0      0      0      0  ...
# 25       215       41  1   0    0      0      0      0      0      0  ...
# 28       171       11  0   1    0      0      0      0      0      0  ...
# 29       160       33  0   1    0      0      0      0      0      0  ...
#
#     Vietnamese, Noodles, Healthy, Asian, Bubble Tea, Family Meals  \
# 4                                                   0
# 8                                                   0
# 25                                                  0
# 28                                                  0
# 29                                                  0
#
#     Vietnamese, Noodles, Healthy, Thai, Vegetarian, Soup, Pho, Rice &amp; Curry, Bubble Tea, Desserts, Local Specialities, Vegetarian Friendly  \
# 4                                                   0
# 8                                                   0
# 25                                                  0
# 28                                                  0
# 29                                                  0
#
#     Vietnamese, Noodles, Healthy, Vegetarian, Vegetarian Friendly, Thai, Rice Dishes, Chinese, Pho  \
# 4                                                   0
# 8                                                   0
# 25                                                  0
# 28                                                  0
# 29                                                  0
#
#     Vietnamese, Sandwich, Family Meals  \
# 4                                    0
# 8                                    0
# 25                                   0
# 28                                   0
# 29                                   0
#
#     Wings, American, Fast Food, Family Meals, Burgers  \
# 4                                                   0
# 8                                                   0
# 25                                                  0
# 28                                                  0
# 29                                                  0
#
#     Wings, Chicken, American  pizza, Sandwich, Salads  \
# 4                          0                        0
# 8                          0                        0
# 25                         0                        0
# 28                         0                        0
# 29                         0                        0
#
#     wings, American, Burgers, Family Friendly  \
# 4                                           0
# 8                                           0
# 25                                          0
# 28                                          0
# 29                                          0
#
#     wings, American, Chicken, Family Friendly  wings, American, Comfort Food
# 4                                           0                              0
# 8                                           0                              0
# 25                                          0                              0
# 28                                          0                              0
# 29                                          0                              0
#
# [5 rows x 439 columns]

# %%
# Reformat data of the independent variable X as a single-column array
X.shape
# Out:
# (558, 439)

# %%
# Reformat data of the independent variable y as a single-column array
y.shape
# Out:
# (558,)

# %%
# Check the balance of our target values
target_value_counts = y.value_counts()
target_value_counts
# Out:
# 5    515
# 4     41
# 3      2
# Name: score, dtype: int64

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# Step 1: Separate the columns to be scaled from the rest of the DataFrame
columns_to_scale = ['position', 'ratings']
X_train_to_scale = data[columns_to_scale]
X_train_rest = data.drop(columns=columns_to_scale)

# Step 2: Initialize and fit the StandardScaler on the selected columns
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_to_scale)

# Step 3: Reconstruct the DataFrame with the scaled columns and the remaining columns
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=columns_to_scale)
X_train = pd.concat([X_train_scaled_df, X_train_rest], axis=1)

#Set all the column names to str type
X_train.columns = [str(col) for col in X_train.columns]

# Assign 'score' as the target column for logistic regression
y_train = data['score']

# %%
# Import the train_test_learn module
from sklearn.model_selection import train_test_split

# Split the data using train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# ## Create a Logistic Regression Model with the Original Data

# %%
# Import the LogisticRegression module from SKLearn
from sklearn.linear_model import LogisticRegression

# Create and fit the logistic regression model using the modified DataFrame
model = LogisticRegression(max_iter=2000)
model.fit(X_train, y_train)
# Out:
# C:\Users\muell\anaconda4\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# LogisticRegression(max_iter=2000)

# %% [markdown]
# ### Make the Prediction Model

# %%
# Make a prediction using the testing data
y_pred = model.predict(X_test)
# Out:
# C:\Users\muell\anaconda4\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(

# %% [markdown]
# ### Logistical Regression Model Assessment

# %%
from sklearn.metrics import balanced_accuracy_score, confusion_matrix, classification_report

# Print the balanced_accuracy score of the model
balanced_accuracy = balanced_accuracy_score(y_test, y_pred)
print("Balanced Accuracy Score:", balanced_accuracy)
# Out:
# Balanced Accuracy Score: 0.5

# %%
# Generate a confusion matrix for the model
confusion_mat = confusion_matrix(y_test, y_pred)

# Print the confusion matrix
print("Confusion Matrix:")
print(confusion_mat)
# Out:
# Confusion Matrix:
# [[  0   9]
#  [  0 131]]

# %%
# Print the classification report for the model
class_report = classification_report(y_test, y_pred, zero_division=1)

print("Logistical Regression Classification Report:")
print(class_report)
# Out:
# Logistical Regression Classification Report:
#               precision    recall  f1-score   support
#
#            4       1.00      0.00      0.00         9
#            5       0.94      1.00      0.97       131
#
#     accuracy                           0.94       140
#    macro avg       0.97      0.50      0.48       140
# weighted avg       0.94      0.94      0.90       140

# %% [markdown]
# ### Create a Logistic Regression Model with Resampled Training Data

# %%
# Import the RandomOverSampler module form imbalanced-learn
from imblearn.over_sampling import RandomOverSampler

# Instantiate the random oversampler model
# # Assign a random_state parameter of 1 to the model
random_oversampler = RandomOverSampler(random_state=1)

#Set all the column names to str type
X_train.columns = [str(col) for col in X_train.columns]

# Fit the original training data to the random_oversampler model
X_train_resampled, y_train_resampled = random_oversampler.fit_resample(X_train, y_train)

# %%
# Count the distinct values of the resampled labels data
label_counts = pd.Series(y_train_resampled).value_counts()
label_counts
# Out:
# 5    384
# 4    384
# 3    384
# Name: score, dtype: int64

# %%
# Instantiate the resampled Logistic Regression model
model = LogisticRegression(max_iter=2000)
                           
# Fit the model using the resampled training data
model.fit(X_train_resampled, y_train_resampled)

# Make a prediction using the testing data
y_pred = model.predict(X_test)
# Out:
# C:\Users\muell\anaconda4\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\muell\anaconda4\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Resampled Logistical Regression Model Assessment

# %%
# Print the balanced_accuracy score of the model 
balanced_accuracy = balanced_accuracy_score(y_test, y_pred)
print("Balanced Accuracy Score:", balanced_accuracy)
# Out:
# Balanced Accuracy Score: 0.5250212044105174

# %%
# Generate a confusion matrix for the model
confusion_mat = confusion_matrix(y_test, y_pred)

# Print the confusion matrix
print("Confusion Matrix:")
print(confusion_mat)
# Out:
# Confusion Matrix:
# [[  1   8]
#  [  8 123]]

# %%
# Print the classification report for the model
class_report = classification_report(y_test, y_pred, zero_division=1)

print("RandomOverSampler Classification Report:")
print(class_report)
# Out:
# RandomOverSampler Classification Report:
#               precision    recall  f1-score   support
#
#            4       0.11      0.11      0.11         9
#            5       0.94      0.94      0.94       131
#
#     accuracy                           0.89       140
#    macro avg       0.53      0.53      0.53       140
# weighted avg       0.89      0.89      0.89       140

# %% [markdown]
# ## K-Means and Clustering

# %%
#Make a copy of the clean dataframe to use just for KMeans
kmeans_copy = restaurants_df_cleaned.copy()
kmeans_copy.head()
# Out:
#        id  position                                               name  score  \
# 4   34522       192    Willie's Grill &amp; Icehouse (7911 Interstate)    4.5
# 8   34527       190                McDonald's® (1643 Pleasanton Road)    4.2
# 25  34547       215  The Philly Cheesesteak Company (1011 N Loop 16...    3.9
# 28  34551       171  Zito's Delicatessen &amp; Sandwich Shop (8800 ...    4.8
# 29  34552       160                Nachos Muchachos (427 Lombrano St,)    3.2
#
#     ratings                                           category price_range  \
# 4      92.0  American, Burgers, Family Friendly, Wings, Alc...           $
# 8     167.0                       American, Fast Food, Burgers           $
# 25     41.0                     American, Sandwiches, Desserts           $
# 28     11.0                      Sandwiches, American, Healthy          $$
# 29     33.0                          American, Mexican, Snacks          $$
#
#           lat        lng                       address          city state  \
# 4   29.350066 -98.537672  7911 Interstate 35 Access Rd   San Antonio    TX
# 8   29.366126 -98.504588            1643 Pleasanton Rd   San Antonio    TX
# 25  29.611140 -98.477810            1011 N Loop 1604 E   San Antonio    TX
# 28  29.520260 -98.460730              8800 Broadway St   San Antonio    TX
# 29  29.441910 -98.510550               427 Lombrano St   San Antonio    TX
#
#     zip_code
# 4    78224.0
# 8    78221.0
# 25   78232.0
# 28   78217.0
# 29   78207.0

# %%
#drop uneccessary columns
kmeans_copy.drop(columns=['id', 'address', 'city', 'state', 'name'], inplace=True)
print(kmeans_copy)
# Out:
#       position  score  ratings  \
# 4          192    4.5     92.0
# 8          190    4.2    167.0
# 25         215    3.9     41.0
# 28         171    4.8     11.0
# 29         160    3.2     33.0
# ...        ...    ...      ...
# 1207       100    4.2     21.0
# 1208        92    4.8    117.0
# 1209        88    4.6     92.0
# 1211        33    4.7    162.0
# 1214       185    4.5    186.0
#
#                                                category price_range  \
# 4     American, Burgers, Family Friendly, Wings, Alc...           $
# 8                          American, Fast Food, Burgers           $
# 25                       American, Sandwiches, Desserts           $
# 28                        Sandwiches, American, Healthy          $$
# 29                            American, Mexican, Snacks          $$
# ...                                                 ...         ...
# 1207                                          Fast Food           $
# 1208                       American, Burgers, Fast Food           $
# 1209  Mexican, Tex Mex, Breakfast and Brunch, Family...           $
# 1211                      Burgers, American, Sandwiches           $
# 1214  Fast Food, American, Family Meals, Family Frie...           $
#
#             lat        lng  zip_code
# 4     29.350066 -98.537672   78224.0
# 8     29.366126 -98.504588   78221.0
# 25    29.611140 -98.477810   78232.0
# 28    29.520260 -98.460730   78217.0
# 29    29.441910 -98.510550   78207.0
# ...         ...        ...       ...
# 1207  29.413326 -98.503869   78204.0
# 1208  29.610843 -98.473864   78232.0
# 1209  29.375656 -98.457137   78223.0
# 1211  29.611254 -98.476393   78232.0
# 1214  29.357883 -98.549789   78211.0
#
# [558 rows x 8 columns]

# %%
#convert 'zip_code' to integer
kmeans_copy['zip_code']=kmeans_copy['zip_code'].astype(int)

#convert 'rating' to integer
kmeans_copy['ratings']=kmeans_copy['ratings'].astype(int)

# %%
#Use get_dummies to convert categorical columns to numerical values
dummy_price = pd.get_dummies(kmeans_copy['price_range'])
dummy_zip = pd.get_dummies(kmeans_copy['zip_code'])
dummy_category = pd.get_dummies(kmeans_copy['category'])

# %%
# Joining the new DataFrame back to the original one
k_data = pd.concat([kmeans_copy, dummy_price, dummy_zip, dummy_category], axis=1)

# Dropping the original 'price_range', category and 'zip_code' columns
k_data = k_data.drop('price_range', axis=1)
k_data = k_data.drop('zip_code', axis=1)
k_data = k_data.drop('category', axis=1)
k_data
# Out:
#       position  score  ratings        lat        lng  $  $$  $$$  75038  \
# 4          192    4.5       92  29.350066 -98.537672  1   0    0      0
# 8          190    4.2      167  29.366126 -98.504588  1   0    0      0
# 25         215    3.9       41  29.611140 -98.477810  1   0    0      0
# 28         171    4.8       11  29.520260 -98.460730  0   1    0      0
# 29         160    3.2       33  29.441910 -98.510550  0   1    0      0
# ...        ...    ...      ...        ...        ... ..  ..  ...    ...
# 1207       100    4.2       21  29.413326 -98.503869  1   0    0      0
# 1208        92    4.8      117  29.610843 -98.473864  1   0    0      0
# 1209        88    4.6       92  29.375656 -98.457137  1   0    0      0
# 1211        33    4.7      162  29.611254 -98.476393  1   0    0      0
# 1214       185    4.5      186  29.357883 -98.549789  1   0    0      0
#
#       78201  ...  \
# 4         0  ...
# 8         0  ...
# 25        0  ...
# 28        0  ...
# 29        0  ...
# ...     ...  ...
# 1207      0  ...
# 1208      0  ...
# 1209      0  ...
# 1211      0  ...
# 1214      0  ...
#
#       Vietnamese, Noodles, Healthy, Asian, Bubble Tea, Family Meals  \
# 4                                                     0
# 8                                                     0
# 25                                                    0
# 28                                                    0
# 29                                                    0
# ...                                                 ...
# 1207                                                  0
# 1208                                                  0
# 1209                                                  0
# 1211                                                  0
# 1214                                                  0
#
#       Vietnamese, Noodles, Healthy, Thai, Vegetarian, Soup, Pho, Rice &amp; Curry, Bubble Tea, Desserts, Local Specialities, Vegetarian Friendly  \
# 4                                                     0
# 8                                                     0
# 25                                                    0
# 28                                                    0
# 29                                                    0
# ...                                                 ...
# 1207                                                  0
# 1208                                                  0
# 1209                                                  0
# 1211                                                  0
# 1214                                                  0
#
#       Vietnamese, Noodles, Healthy, Vegetarian, Vegetarian Friendly, Thai, Rice Dishes, Chinese, Pho  \
# 4                                                     0
# 8                                                     0
# 25                                                    0
# 28                                                    0
# 29                                                    0
# ...                                                 ...
# 1207                                                  0
# 1208                                                  0
# 1209                                                  0
# 1211                                                  0
# 1214                                                  0
#
#       Vietnamese, Sandwich, Family Meals  \
# 4                                      0
# 8                                      0
# 25                                     0
# 28                                     0
# 29                                     0
# ...                                  ...
# 1207                                   0
# 1208                                   0
# 1209                                   0
# 1211                                   0
# 1214                                   0
#
#       Wings, American, Fast Food, Family Meals, Burgers  \
# 4                                                     0
# 8                                                     0
# 25                                                    0
# 28                                                    0
# 29                                                    0
# ...                                                 ...
# 1207                                                  0
# 1208                                                  0
# 1209                                                  0
# 1211                                                  0
# 1214                                                  0
#
#       Wings, Chicken, American  pizza, Sandwich, Salads  \
# 4                            0                        0
# 8                            0                        0
# 25                           0                        0
# 28                           0                        0
# 29                           0                        0
# ...                        ...                      ...
# 1207                         0                        0
# 1208                         0                        0
# 1209                         0                        0
# 1211                         0                        0
# 1214                         0                        0
#
#       wings, American, Burgers, Family Friendly  \
# 4                                             0
# 8                                             0
# 25                                            0
# 28                                            0
# 29                                            0
# ...                                         ...
# 1207                                          0
# 1208                                          0
# 1209                                          0
# 1211                                          0
# 1214                                          0
#
#       wings, American, Chicken, Family Friendly  wings, American, Comfort Food
# 4                                             0                              0
# 8                                             0                              0
# 25                                            0                              0
# 28                                            0                              0
# 29                                            0                              0
# ...                                         ...                            ...
# 1207                                          0                              0
# 1208                                          0                              0
# 1209                                          0                              0
# 1211                                          0                              0
# 1214                                          0                              0
#
# [558 rows x 442 columns]

# %%
# Start by importing the K-means algorithm
from sklearn.cluster import KMeans

# Create and initialize the K-means model instance for 3 clusters
model = KMeans(n_clusters=5, random_state=42)

# Print the model
model
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
# Extract the score column for clustering
score_data = k_data[['score']]

# Initialize and fit the KMeans model
cluster_assignments = model.fit_predict(score_data)

# Add the cluster assignments back to the DataFrame
k_data['cluster'] = cluster_assignments

# Optional: Visualize the clusters
plt.scatter(score_data, cluster_assignments, c=cluster_assignments, cmap='rainbow')
plt.xlabel('Score')
plt.ylabel('Cluster')
plt.title('K-means Clustering of Restaurant Scores')
plt.show()

# Print the number of restaurants in each cluster
print(k_data['cluster'].value_counts())
# Out:
# 0    223
# 4    168
# 1    109
# 3     45
# 2     13
# Name: cluster, dtype: int64

# %%
# Extract the score column for clustering
score_data = k_data[['score']]

# Initialize and fit the KMeans model
cluster_assignments = model.fit_predict(score_data)

# Add the cluster assignments back to the DataFrame
k_data['cluster'] = cluster_assignments


# Scatterplot of restaurant scores with clustered dots
plt.figure(figsize=(10, 6))
plt.scatter(k_data['ratings'], k_data['score'], c=k_data['cluster'], cmap='gist_rainbow')
plt.xlabel('Number of Ratings')
plt.ylabel('Score')
plt.title('Restaurant Scores and Clusters')
plt.colorbar(label='Cluster')
plt.show()

# %%
k_data.head()
# Out:
#     position  score  ratings        lat        lng  $  $$  $$$  75038  78201  \
# 4        192    4.5       92  29.350066 -98.537672  1   0    0      0      0
# 8        190    4.2      167  29.366126 -98.504588  1   0    0      0      0
# 25       215    3.9       41  29.611140 -98.477810  1   0    0      0      0
# 28       171    4.8       11  29.520260 -98.460730  0   1    0      0      0
# 29       160    3.2       33  29.441910 -98.510550  0   1    0      0      0
#
#     ...  \
# 4   ...
# 8   ...
# 25  ...
# 28  ...
# 29  ...
#
#     Vietnamese, Noodles, Healthy, Thai, Vegetarian, Soup, Pho, Rice &amp; Curry, Bubble Tea, Desserts, Local Specialities, Vegetarian Friendly  \
# 4                                                   0
# 8                                                   0
# 25                                                  0
# 28                                                  0
# 29                                                  0
#
#     Vietnamese, Noodles, Healthy, Vegetarian, Vegetarian Friendly, Thai, Rice Dishes, Chinese, Pho  \
# 4                                                   0
# 8                                                   0
# 25                                                  0
# 28                                                  0
# 29                                                  0
#
#     Vietnamese, Sandwich, Family Meals  \
# 4                                    0
# 8                                    0
# 25                                   0
# 28                                   0
# 29                                   0
#
#     Wings, American, Fast Food, Family Meals, Burgers  \
# 4                                                   0
# 8                                                   0
# 25                                                  0
# 28                                                  0
# 29                                                  0
#
#     Wings, Chicken, American  pizza, Sandwich, Salads  \
# 4                          0                        0
# 8                          0                        0
# 25                         0                        0
# 28                         0                        0
# 29                         0                        0
#
#     wings, American, Burgers, Family Friendly  \
# 4                                           0
# 8                                           0
# 25                                          0
# 28                                          0
# 29                                          0
#
#     wings, American, Chicken, Family Friendly  wings, American, Comfort Food  \
# 4                                           0                              0
# 8                                           0                              0
# 25                                          0                              0
# 28                                          0                              0
# 29                                          0                              0
#
#     cluster
# 4         4
# 8         1
# 25        3
# 28        0
# 29        2
#
# [5 rows x 443 columns]

# %%
k_data['cluster'].value_counts()
# Out:
# 0    223
# 4    168
# 1    109
# 3     45
# 2     13
# Name: cluster, dtype: int64

# %%
k_data.query("cluster==2")
# Out:
#       position  score  ratings        lat        lng  $  $$  $$$  75038  \
# 29         160    3.2       33  29.441910 -98.510550  0   1    0      0
# 68         141    3.3       15  29.438020 -98.541740  1   0    0      0
# 367          6    3.6       20  29.425367 -98.489608  1   0    0      0
# 503        148    3.5       21  29.441910 -98.510550  1   0    0      0
# 530        100    3.6       16  29.519850 -98.484490  0   1    0      0
# 531         99    2.9       67  29.438020 -98.541740  1   0    0      0
# 769         17    2.9       15  29.575600 -98.418690  1   0    0      0
# 774         12    3.1       26  29.438160 -98.541720  0   1    0      0
# 776         10    3.2       26  29.574970 -98.418310  1   0    0      0
# 852        225    3.5       26  29.547840 -98.376370  1   0    0      0
# 1083       126    3.4       12  29.492630 -98.555280  1   0    0      0
# 1086       133    3.6       23  29.560670 -98.484240  1   0    0      0
# 1117        62    3.6       29  29.446157 -98.361840  0   1    0      0
#
#       78201  ...  \
# 29        0  ...
# 68        0  ...
# 367       0  ...
# 503       0  ...
# 530       0  ...
# 531       0  ...
# 769       0  ...
# 774       0  ...
# 776       0  ...
# 852       0  ...
# 1083      0  ...
# 1086      0  ...
# 1117      0  ...
#
#       Vietnamese, Noodles, Healthy, Thai, Vegetarian, Soup, Pho, Rice &amp; Curry, Bubble Tea, Desserts, Local Specialities, Vegetarian Friendly  \
# 29                                                    0
# 68                                                    0
# 367                                                   0
# 503                                                   0
# 530                                                   0
# 531                                                   0
# 769                                                   0
# 774                                                   0
# 776                                                   0
# 852                                                   0
# 1083                                                  0
# 1086                                                  0
# 1117                                                  0
#
#       Vietnamese, Noodles, Healthy, Vegetarian, Vegetarian Friendly, Thai, Rice Dishes, Chinese, Pho  \
# 29                                                    0
# 68                                                    0
# 367                                                   0
# 503                                                   0
# 530                                                   0
# 531                                                   0
# 769                                                   0
# 774                                                   0
# 776                                                   0
# 852                                                   0
# 1083                                                  0
# 1086                                                  0
# 1117                                                  0
#
#       Vietnamese, Sandwich, Family Meals  \
# 29                                     0
# 68                                     0
# 367                                    0
# 503                                    0
# 530                                    0
# 531                                    0
# 769                                    0
# 774                                    0
# 776                                    0
# 852                                    0
# 1083                                   0
# 1086                                   0
# 1117                                   0
#
#       Wings, American, Fast Food, Family Meals, Burgers  \
# 29                                                    0
# 68                                                    0
# 367                                                   0
# 503                                                   0
# 530                                                   0
# 531                                                   0
# 769                                                   0
# 774                                                   0
# 776                                                   0
# 852                                                   0
# 1083                                                  0
# 1086                                                  0
# 1117                                                  0
#
#       Wings, Chicken, American  pizza, Sandwich, Salads  \
# 29                           0                        0
# 68                           0                        0
# 367                          0                        0
# 503                          0                        0
# 530                          0                        0
# 531                          0                        0
# 769                          0                        0
# 774                          0                        0
# 776                          0                        0
# 852                          0                        0
# 1083                         0                        0
# 1086                         0                        0
# 1117                         0                        0
#
#       wings, American, Burgers, Family Friendly  \
# 29                                            0
# 68                                            0
# 367                                           0
# 503                                           0
# 530                                           0
# 531                                           0
# 769                                           0
# 774                                           0
# 776                                           0
# 852                                           0
# 1083                                          0
# 1086                                          0
# 1117                                          0
#
#       wings, American, Chicken, Family Friendly  \
# 29                                            0
# 68                                            0
# 367                                           0
# 503                                           0
# 530                                           0
# 531                                           0
# 769                                           0
# 774                                           0
# 776                                           0
# 852                                           0
# 1083                                          0
# 1086                                          0
# 1117                                          0
#
#       wings, American, Comfort Food  cluster
# 29                                0        2
# 68                                0        2
# 367                               0        2
# 503                               0        2
# 530                               0        2
# 531                               0        2
# 769                               0        2
# 774                               0        2
# 776                               0        2
# 852                               0        2
# 1083                              0        2
# 1086                              0        2
# 1117                              0        2
#
# [13 rows x 443 columns]

# %%
restaurants_df_cleaned.head()
# Out:
#        id  position                                               name  score  \
# 4   34522       192    Willie's Grill &amp; Icehouse (7911 Interstate)    4.5
# 8   34527       190                McDonald's® (1643 Pleasanton Road)    4.2
# 25  34547       215  The Philly Cheesesteak Company (1011 N Loop 16...    3.9
# 28  34551       171  Zito's Delicatessen &amp; Sandwich Shop (8800 ...    4.8
# 29  34552       160                Nachos Muchachos (427 Lombrano St,)    3.2
#
#     ratings                                           category price_range  \
# 4      92.0  American, Burgers, Family Friendly, Wings, Alc...           $
# 8     167.0                       American, Fast Food, Burgers           $
# 25     41.0                     American, Sandwiches, Desserts           $
# 28     11.0                      Sandwiches, American, Healthy          $$
# 29     33.0                          American, Mexican, Snacks          $$
#
#           lat        lng                       address          city state  \
# 4   29.350066 -98.537672  7911 Interstate 35 Access Rd   San Antonio    TX
# 8   29.366126 -98.504588            1643 Pleasanton Rd   San Antonio    TX
# 25  29.611140 -98.477810            1011 N Loop 1604 E   San Antonio    TX
# 28  29.520260 -98.460730              8800 Broadway St   San Antonio    TX
# 29  29.441910 -98.510550               427 Lombrano St   San Antonio    TX
#
#     zip_code
# 4    78224.0
# 8    78221.0
# 25   78232.0
# 28   78217.0
# 29   78207.0

# %%
# Add the cluster assignments back to the DataFrame
restaurants_df_cleaned['cluster'] = cluster_assignments

restaurants_df_cleaned.head()
# Out:
# C:\Users\muell\AppData\Local\Temp\ipykernel_17536\2234554621.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   restaurants_df_cleaned['cluster'] = cluster_assignments
#        id  position                                               name  score  \
# 4   34522       192    Willie's Grill &amp; Icehouse (7911 Interstate)    4.5
# 8   34527       190                McDonald's® (1643 Pleasanton Road)    4.2
# 25  34547       215  The Philly Cheesesteak Company (1011 N Loop 16...    3.9
# 28  34551       171  Zito's Delicatessen &amp; Sandwich Shop (8800 ...    4.8
# 29  34552       160                Nachos Muchachos (427 Lombrano St,)    3.2
#
#     ratings                                           category price_range  \
# 4      92.0  American, Burgers, Family Friendly, Wings, Alc...           $
# 8     167.0                       American, Fast Food, Burgers           $
# 25     41.0                     American, Sandwiches, Desserts           $
# 28     11.0                      Sandwiches, American, Healthy          $$
# 29     33.0                          American, Mexican, Snacks          $$
#
#           lat        lng                       address          city state  \
# 4   29.350066 -98.537672  7911 Interstate 35 Access Rd   San Antonio    TX
# 8   29.366126 -98.504588            1643 Pleasanton Rd   San Antonio    TX
# 25  29.611140 -98.477810            1011 N Loop 1604 E   San Antonio    TX
# 28  29.520260 -98.460730              8800 Broadway St   San Antonio    TX
# 29  29.441910 -98.510550               427 Lombrano St   San Antonio    TX
#
#     zip_code  cluster
# 4    78224.0        4
# 8    78221.0        1
# 25   78232.0        3
# 28   78217.0        0
# 29   78207.0        2

# %%
cluster_zero = restaurants_df_cleaned.query("cluster==0")
cluster_zero
# Out:
#          id  position                                               name  \
# 28    34551       171  Zito's Delicatessen &amp; Sandwich Shop (8800 ...
# 35    34558        78                             El Pilon Sabor Boriqua
# 37    34561        56   La Madeleine Country French Cafe (4820 Broadway)
# 38    34562        27                                 El Jarro De Arturo
# 74    34604       106          Jason's Deli (9933 IH -10 West, Colonade)
# ...     ...       ...                                                ...
# 1203  35966       171         Smoothie King (1141 N Loop 1604 East #106)
# 1204  35967       164                       Subway (903 East Bitters Rd)
# 1206  35969       129                Firehouse Subs (South Park Commons)
# 1208  35971        92        Five Guys TX-1098 1321 North Loop 1604 East
# 1211  35976        33           Jason's Deli (1141 N. Fm 1604 East #108)
#
#       score  ratings                                       category  \
# 28      4.8     11.0                  Sandwiches, American, Healthy
# 35      4.8     73.0                                   Puerto Rican
# 37      4.7    146.0                        European, French, Pasta
# 38      4.8     24.0  Salads, Chicken, Pasta, Family Meals, Healthy
# 74      4.7    200.0                  Burgers, American, Sandwiches
# ...     ...      ...                                            ...
# 1203    4.7     55.0         American, Healthy, Juice and Smoothies
# 1204    4.9     10.0                  Fast Food, Sandwich, American
# 1206    4.8     68.0                                 Sandwich, Deli
# 1208    4.8    117.0                   American, Burgers, Fast Food
# 1211    4.7    162.0                  Burgers, American, Sandwiches
#
#      price_range        lat        lng                            address  \
# 28            $$  29.520260 -98.460730                   8800 Broadway St
# 35             $  29.469805 -98.438646             1127 Harry Wurzbach Rd
# 37             $  29.470949 -98.462880                      4820 Broadway
# 38            $$  29.565009 -98.484089                13421 San Pedro Ave
# 74             $  29.534245 -98.564129            9933 West Interstate 10
# ...          ...        ...        ...                                ...
# 1203          $$  29.611160 -98.476380         1141 N Loop 1604 East #106
# 1204           $  29.562833 -98.479302                903 East Bitters Rd
# 1206           $  29.355665 -98.542949  2814 South West Military Dr. #107
# 1208           $  29.610843 -98.473864         1321 N Loop 1604 Suite 105
# 1211           $  29.611254 -98.476393            1141 North FM 1604 East
#
#               city state  zip_code  cluster
# 28     San Antonio    TX   78217.0        0
# 35     San Antonio    TX   78209.0        0
# 37     San Antonio    TX   78209.0        0
# 38     San Antonio    TX   78216.0        0
# 74     San Antonio    TX   78230.0        0
# ...            ...   ...       ...      ...
# 1203   San Antonio    TX   78258.0        0
# 1204   San Antonio    TX   78216.0        0
# 1206   San Antonio    TX   78224.0        0
# 1208   San Antonio    TX   78232.0        0
# 1211   San Antonio    TX   78232.0        0
#
# [223 rows x 14 columns]

# %%
cluster_zero['category'].value_counts()
# Out:
# Burgers, American, Sandwiches                                                  9
# Mexican, Latin American, New Mexican                                           8
# Convenience, Everyday Essentials, Snacks, Home &amp; Personal Care, Alcohol    4
# Thai, Asian, Noodles                                                           4
# Alcohol, Drinks, Liquor Stores, Wine                                           4
#                                                                               ..
# Comfort Food, American, Chicken                                                1
# Sandwich, American, Comfort Food                                               1
# American, Comfort Food, Kids Friendly                                          1
# Indian, Indian Curry, Family Friendly                                          1
# American, Burgers, Fast Food                                                   1
# Name: category, Length: 179, dtype: int64

# %%
restaurants_df_cleaned.query("cluster==4")
# Out:
#          id  position                                               name  \
# 4     34522       192    Willie's Grill &amp; Icehouse (7911 Interstate)
# 36    34559        74  54th Street Restaurant &amp; Drafthouse - (Rec...
# 62    34592       158                            Applebee's (North Star)
# 63    34593       154                            The County Line - IH 10
# 73    34603       111                            Kona Grill (North Star)
# ...     ...       ...                                                ...
# 1185  35942       171                    Wendy's  (19170 STONE OAK PKWY)
# 1186  35943        83  Cracker Barrel Old Country Store (98 NE Loop 410)
# 1198  35959        58                               IHOP (3820 Broadway)
# 1209  35972        88                    Taco Cabana (2347 E Southcross)
# 1214  35980       185                               Bush's Chicken (SWM)
#
#       score  ratings                                           category  \
# 4       4.5     92.0  American, Burgers, Family Friendly, Wings, Alc...
# 36      4.6    153.0        Burgers, American, Sandwiches, Family Meals
# 62      4.5    122.0  American, Burgers, Salads, Healthy, Family Fri...
# 63      4.5     36.0                                      BBQ, American
# 73      4.5     41.0                                    American, Sushi
# ...     ...      ...                                                ...
# 1185    4.6     71.0                       American, Burgers, Fast Food
# 1186    4.5    173.0        Burgers, American, Sandwiches, Family Meals
# 1198    4.6    106.0  American, Breakfast and Brunch, burger, Comfor...
# 1209    4.6     92.0  Mexican, Tex Mex, Breakfast and Brunch, Family...
# 1214    4.5    186.0  Fast Food, American, Family Meals, Family Frie...
#
#      price_range        lat        lng                       address  \
# 4              $  29.350066 -98.537672  7911 Interstate 35 Access Rd
# 36             $  29.516489 -98.478893        954 East Rector Street
# 62            $$  29.521071 -98.484781               97 Loop 410 NE.
# 63            $$  29.537479 -98.567348              10101 IH-10 West
# 73            $$  29.518406 -98.495259            7400 San Pedro Ave
# ...          ...        ...        ...                           ...
# 1185           $  29.624939 -98.494496          19170 STONE OAK PKWY
# 1186           $  29.519321 -98.484431                98 NE Loop 410
# 1198           $  29.461757 -98.465960                 3820 Broadway
# 1209           $  29.375656 -98.457137             2347 E Southcross
# 1214           $  29.357883 -98.549789           3219 SW Military Dr
#
#               city state  zip_code  cluster
# 4      San Antonio    TX   78224.0        4
# 36     San Antonio    TX   78216.0        4
# 62     San Antonio    TX   78216.0        4
# 63     San Antonio    TX   78230.0        4
# 73     San Antonio    TX   78216.0        4
# ...            ...   ...       ...      ...
# 1185   SAN ANTONIO    TX   78258.0        4
# 1186   SAN ANTONIO    TX   78216.0        4
# 1198   San Antonio    TX   78209.0        4
# 1209   San Antonio    TX   78223.0        4
# 1214   San Antonio    TX   78211.0        4
#
# [168 rows x 14 columns]

# %%
cluster_scores = restaurants_df_cleaned.groupby('cluster')['score'].apply(list)
# Print out the scores in each cluster
for cluster, scores in cluster_scores.items():
    print(f"Cluster {cluster}: {scores}")
# Out:
# Cluster 0: [4.8, 4.8, 4.7, 4.8, 4.7, 4.9, 4.7, 4.7, 4.7, 4.9, 4.9, 4.7, 4.7, 4.8, 4.8, 4.8, 4.7, 5.0, 4.7, 4.9, 4.8, 5.0, 4.7, 4.8, 4.8, 4.7, 4.8, 4.8, 4.8, 4.9, 4.7, 4.9, 4.8, 4.7, 4.8, 4.8, 4.7, 4.8, 4.8, 4.7, 4.7, 4.7, 4.7, 4.9, 4.9, 4.7, 4.8, 4.7, 4.7, 4.9, 4.7, 4.7, 4.7, 4.7, 4.8, 4.8, 4.7, 4.7, 4.7, 4.8, 4.7, 4.8, 4.8, 5.0, 4.9, 4.7, 4.8, 4.8, 4.7, 4.7, 4.8, 4.8, 4.9, 4.9, 4.7, 4.7, 4.7, 4.7, 4.7, 4.8, 4.7, 4.7, 4.7, 4.7, 4.7, 4.8, 4.8, 4.9, 4.7, 4.8, 4.8, 4.9, 4.9, 4.8, 4.9, 4.7, 4.7, 4.8, 4.8, 4.7, 4.7, 4.8, 4.7, 4.8, 4.7, 4.7, 4.7, 4.9, 4.8, 4.7, 4.8, 4.7, 4.8, 4.8, 4.7, 4.7, 4.8, 4.8, 4.7, 4.7, 4.7, 4.7, 4.7, 4.7, 4.8, 4.7, 4.8, 4.8, 4.8, 4.7, 4.7, 4.7, 5.0, 4.9, 5.0, 4.8, 4.7, 5.0, 4.7, 4.8, 4.7, 4.8, 4.9, 4.7, 4.8, 4.9, 4.8, 4.9, 5.0, 4.9, 4.9, 4.8, 5.0, 4.9, 4.9, 5.0, 4.8, 4.7, 4.8, 4.8, 4.7, 5.0, 4.8, 4.7, 4.7, 4.7, 4.8, 4.8, 4.9, 4.9, 4.8, 4.9, 4.7, 4.9, 4.7, 5.0, 4.7, 4.8, 4.9, 4.7, 4.8, 4.7, 4.9, 4.9, 4.9, 4.8, 4.9, 4.7, 5.0, 4.8, 5.0, 4.7, 4.8, 4.8, 4.8, 4.9, 4.7, 4.7, 4.8, 4.7, 4.9, 4.7, 4.8, 4.8, 4.8, 4.8, 4.7, 4.8, 4.7, 4.8, 4.7, 4.7, 4.9, 4.8, 4.8, 4.7, 4.8, 4.8, 4.7, 4.9, 4.8, 4.8, 4.7]
# Cluster 1: [4.2, 4.2, 4.4, 4.4, 4.4, 4.4, 4.4, 4.3, 4.4, 4.2, 4.3, 4.3, 4.2, 4.4, 4.4, 4.3, 4.4, 4.2, 4.4, 4.3, 4.2, 4.2, 4.4, 4.3, 4.3, 4.3, 4.3, 4.4, 4.4, 4.3, 4.3, 4.3, 4.2, 4.4, 4.2, 4.4, 4.4, 4.4, 4.3, 4.3, 4.4, 4.2, 4.4, 4.4, 4.4, 4.3, 4.3, 4.2, 4.4, 4.4, 4.2, 4.3, 4.4, 4.3, 4.2, 4.3, 4.4, 4.4, 4.3, 4.4, 4.4, 4.4, 4.4, 4.3, 4.3, 4.3, 4.2, 4.2, 4.3, 4.3, 4.2, 4.2, 4.4, 4.4, 4.3, 4.2, 4.2, 4.4, 4.4, 4.3, 4.4, 4.3, 4.4, 4.3, 4.4, 4.4, 4.2, 4.2, 4.4, 4.4, 4.4, 4.3, 4.4, 4.2, 4.4, 4.2, 4.4, 4.4, 4.4, 4.4, 4.4, 4.4, 4.2, 4.4, 4.2, 4.3, 4.3, 4.4, 4.2]
# Cluster 2: [3.2, 3.3, 3.6, 3.5, 3.6, 2.9, 2.9, 3.1, 3.2, 3.5, 3.4, 3.6, 3.6]
# Cluster 3: [3.9, 4.1, 4.0, 3.9, 3.9, 3.8, 4.1, 4.1, 3.9, 4.1, 4.0, 4.1, 3.8, 4.0, 4.1, 4.1, 4.1, 3.9, 4.0, 3.8, 3.9, 3.7, 4.0, 4.1, 4.0, 4.1, 3.9, 4.0, 4.0, 3.9, 3.8, 3.7, 3.8, 3.9, 3.9, 4.1, 3.9, 3.8, 4.1, 3.8, 4.1, 4.1, 4.0, 4.1, 3.9]
# Cluster 4: [4.5, 4.6, 4.5, 4.5, 4.5, 4.5, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.5, 4.6, 4.6, 4.6, 4.5, 4.5, 4.5, 4.6, 4.5, 4.6, 4.6, 4.6, 4.5, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.5, 4.6, 4.5, 4.6, 4.6, 4.6, 4.5, 4.6, 4.5, 4.6, 4.6, 4.5, 4.6, 4.6, 4.6, 4.5, 4.5, 4.6, 4.5, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.5, 4.6, 4.5, 4.5, 4.5, 4.6, 4.5, 4.6, 4.5, 4.6, 4.5, 4.6, 4.6, 4.5, 4.5, 4.6, 4.6, 4.6, 4.6, 4.5, 4.6, 4.6, 4.5, 4.5, 4.5, 4.5, 4.5, 4.6, 4.6, 4.5, 4.5, 4.5, 4.6, 4.6, 4.5, 4.5, 4.5, 4.5, 4.6, 4.6, 4.5, 4.6, 4.6, 4.6, 4.6, 4.5, 4.6, 4.6, 4.5, 4.6, 4.6, 4.6, 4.5, 4.6, 4.6, 4.6, 4.6, 4.5, 4.6, 4.6, 4.5, 4.5, 4.6, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.6, 4.5, 4.5, 4.5, 4.5, 4.6, 4.6, 4.5, 4.5, 4.6, 4.5, 4.5, 4.6, 4.6, 4.6, 4.5, 4.6, 4.6, 4.5, 4.5, 4.5, 4.5, 4.6, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.6, 4.5, 4.6, 4.6, 4.5, 4.5, 4.6, 4.5, 4.6, 4.6, 4.5]

# %%
cluster_categories = restaurants_df_cleaned.groupby('cluster')['category'].apply(list)
# Print out the scores in each cluster
for cluster, category in cluster_categories.items():
    print(f"Cluster {cluster}: {category}")
# Out:
# Cluster 0: ['Sandwiches, American, Healthy', 'Puerto Rican', 'European, French, Pasta', 'Salads, Chicken, Pasta, Family Meals, Healthy', 'Burgers, American, Sandwiches', 'Ice Cream &amp; Frozen Yogurt, Comfort Food, Desserts', 'Comfort Food, Street Food, Argentinian', 'Middle Eastern', 'Ice Cream + Frozen Yogurt, Desserts', 'Breakfast and Brunch, Deli, Sandwiches, Bagels, Salads, Hot Dog, Coffee and Tea', 'Bakery, Cupcakes, Comfort Food', 'Breakfast and Brunch, Family Meals, Sandwich, Salads, Pasta, Cafe', 'pizza, Sandwich, Salads', 'Mediterranean, Family Friendly', 'Healthy, Salads, Vegan', 'Dinner, Healthy, Salads', 'Deli, Salads, Sandwich, Healthy', 'Ice Cream + Frozen Yogurt, Desserts, Family Meals', 'Snacks, Bakery, Pastry, Desserts, Desserts', 'American, Fried Chicken, Family Meals, Southern, Sandwich, Fast Food', 'Burgers, American, Sandwiches', 'Mexican, Latin American, New Mexican, Breakfast and Brunch, American', 'Mexican, Family Meals, New Mexican', 'Desserts, Breakfast and Brunch', 'Burgers, American, Sandwiches', 'Bakery, Dount, Coffee and Tea', 'Mexican', 'Salads, Sandwich, Deli, Desserts, Healthy, Family Meals', 'Desserts', 'Pastry, Sandwich, Salads, Healthy', 'Asian, Asian Fusion, Korean', 'Japanese, Hawaiian, Seafood', 'Sushi', 'Japanese, Sushi, Family Friendly', 'Asian Fusion, Asian, Korean', 'Vietnamese, Sandwich, Family Meals', 'Mexican, Salads, Sandwich, Exclusive to Eats', 'Mexican, Latin American, New Mexican', 'Italian, Pizza', 'Mediterranean, Burgers, Wings, Desserts, Sandwich, Salads, Family Meals, Healthy', 'Thai, Asian, Noodles', 'Thai, Asian, Noodles', 'Mexican, Latin American, New Mexican', 'Asian Fusion, Asian, Korean', 'Chinese, Asian, Asian Fusion, Healthy, Seafood', 'Indian, Vegetarian, Asian, Healthy', 'Mediterranean, Greek, Vegetarian', 'Chinese, Asian, Asian Fusion', 'Sushi, Japanese', 'Vegetarian, Healthy, Sandwich', 'Thai, Sushi, Family Meals, Asian, Rice &amp; Curry, Soup, Noodles', 'Sushi, Chinese, Asian, Family Meals', 'Thai, Asian, Noodles', 'Mediterranean, Greek, Vegetarian, Healthy', 'Vegetarian, Healthy, Salads', 'Seafood, American, Southern', 'Puerto Rican', 'Indian, Family Meals', 'Indian', 'Chinese', 'Mediterranean', 'Breakfast and Brunch, Latin American, Asian', 'Mexican, Latin American, New Mexican, BBQ', 'Ice Cream + Frozen Yogurt, Desserts, Comfort Food', 'Sandwiches, American, Healthy', 'Mexican, Latin American, New Mexican, Exclusive to Eats', 'Mexican, Latin American, New Mexican', 'Mexican, Latin American, New Mexican, Tacos, Burritos, Soup, Seafood, Tex Mex', 'Mexican, Latin American, New Mexican, South American, Fish and Chips, Seafood, Burritos, Tacos, Tex Mex, Soup', 'Mexican, Latin American, New Mexican', 'Sandwiches, American, Healthy, Greek, Mediterranean', 'Mexican, Latin American, New Mexican', 'Mexican, Latin American, New Mexican', 'Burgers, American, Sandwiches', 'Mexican, Latin American, New Mexican', 'Mexican, Latin American, New Mexican, Family Meals', 'Mexican, Breakfast and Brunch, Tacos', 'American, Diner', 'Breakfast and Brunch, American, Sandwiches', 'Burgers, American, Sandwiches, Wings, Chicken, Fast Food', 'American, Breakfast &amp; Brunch, Comfort Food', 'Burgers, American, Sandwiches', 'American, Burgers', 'American', 'American', 'Comfort Food, American, Chicken', 'Mexican, Latin American, New Mexican', 'Sandwich, American, Comfort Food', 'American, Comfort Food, Kids Friendly', 'Indian, Indian Curry, Family Friendly', 'American, Fried Chicken, Family Meals, Southern, Sandwich, Fast Food, Group Friendly', 'Salads, Mexican, Vegetarian, Vegetarian Friendly, Vegan', 'Pizza, American, Salads, Healthy', 'American, Salads, Comfort Food, Family Meals, Healthy, Family Friendly', 'Ice Cream &amp; Frozen Yogurt, Comfort Food, Desserts, Allergy Friendly', 'Sandwich, Pasta, Pizza, Salads, Chicken, Steak, Seafood, Kids Friendly, Desserts', 'Desserts, Bakery, Breakfast and Brunch, Coffee and Tea, Comfort Food, Vegan, Vegan Friendly, Vegetarian, Vegetarian Frie ...
# Cluster 1: ['American, Fast Food, Burgers', 'Sandwich, Fast Food, burger, Hot Dog, American', 'BBQ, American, Burgers', 'Sandwich, American, Comfort Food', 'Mexican, Tex Mex, Breakfast and Brunch, Family Meals', 'wings, American, Comfort Food', 'American, Breakfast and Brunch, burger, Comfort Food, Dinner, Omelette, salad, Traditional American, Family Meals', 'American, Bakery, Desserts', 'Mexican, Tex Mex, Breakfast and Brunch, Family Meals', 'Mexican', 'Burgers, American, Desserts', 'Mexican, Breakfast and Brunch, Tacos', 'Breakfast and Brunch, American, Sandwiches', 'Burgers, American, Sandwiches', 'Mexican, Burritos, Tacos, Quesadillas', 'American, Family Meals, Fish and Chips, Seafood, Chicken', 'Pizza, Wings', 'Mexican, South American', 'Asian, Asian Fusion, Korean', 'Chinese, Asian, Chicken', 'Asian, Asian Fusion, Comfort Food', 'Black-owned, Moroccan, Mediterranean, Desserts', 'Chinese, Asian, Noodles, Asian-owned', 'Chinese, Asian, Chicken', 'American, Italian, Pizza, Family Meals', 'Chinese, Seafood, Noodles', 'Asian, Asian Fusion, Korean', 'Chinese, Vietnamese, Asian', 'Chinese, Asian, Asian Fusion', 'Mexican', 'Seafood, Mexican, Tex Mex', 'American, Barfood, Wings, Seafood, Fish and Chips, Desserts, Fast Food, Bar Food, Sandwich', 'Steakhouse, American', 'Seafood, American, Southern, Healthy, Desserts', 'American, Burgers, Sandwich, Salads, Wings, Comfort Food, Hot Dog', 'Mexican, Latin American, New Mexican', 'Mexican, Latin American, New Mexican, Family Meals', 'Mexican, Latin American, Comfort Food', 'Mexican, Latin American', 'Pizza, American, Italian', 'Mexican, Latin American, New Mexican', 'American, Burgers, Comfort Food, Pasta, Sandwich', 'Mexican, Latin American, New Mexican', 'American', 'Black-owned, Mexican, Latin American, New Mexican, Family Meals', 'American, Family Meals', 'American, Burgers, Fast Food', 'Ice Cream + Frozen Yogurt, Burgers, Chicken, American', 'American, Burgers, Pizza, Family Meals', 'Burgers, American, Sandwiches, Family Meals', 'Italian, Pizza, Family Friendly', 'Mexican, Seafood, Kids Friendly, Family Meals', 'Indian, Indian Curry, North Indian, South Indian, Asian, Vegetarian Friendly, Family Friendly', 'American, Breakfast and Brunch, burger, Comfort Food, Dinner, Omelette, salad, Traditional American, Family Meals, Family Friendly', 'Indian, Family Friendly, Group Friendly, Vegetarian, Vegetarian Friendly', 'Mexican, Latin American, New Mexican, Tacos, Breakfast and Brunch, Sandwiches, Sandwich, Kids Friendly, Seafood, Soup', 'Japanese, Family Friendly', 'Mexican, Latin American, New Mexican, Allergy Friendly', 'wings, American, Burgers, Family Friendly', 'Mexican, Group Friendly', 'Thai, Sushi, Asian, Family Friendly, Chinese, Noodles, Rice &amp; Curry, Rice Dishes, Desserts, Coffee and Tea, Fish &amp; Seafood, Vegetarian Friendly', 'American, Traditional American, Burgers, Alcohol', 'American, Wings, Chicken, Alcohol', 'Fast Food, Sandwich, American', 'American, Fast Food, Burgers', 'Alcohol, Drinks, Wine, Liquor Stores', 'Mexican, Latin American, New Mexican', 'Wings, Chicken, American', 'American, Burgers, Fast Food', 'Fast Food, Family Meals', 'Burgers, American, Sandwiches, Wings', 'American, Burgers, Salads, Healthy, Family Friendly, Comfort Food, Pasta, Sandwiches, Steak, Wings', 'Black-owned, African, Ethiopian', 'American, Wings, Comfort Food', 'Hot Dog, American, Comfort Food', 'Burgers, American, Sandwiches', 'Mexican, Desserts', 'Mexican, Tex Mex, Breakfast and Brunch, Family Meals', 'Desserts, Ice Cream + Frozen Yogurt', 'Fast Food', 'Burritos, Fast Food, Mexican', 'American, Breakfast and Brunch, Coffee and Tea, Diner, Desserts, Salads, Steak, Sandwich, Family Meals, Healthy', 'Mediterranean', 'American, burger, Fast Food', 'Fast Food', 'Mexican, Breakfast and Brunch, Snacks, Family Meals, Tacos, Chicken, Asado, Fish &amp; Seafood, Salads', 'Seafood, Chicken, Family Meals, Fish and Chips, American', 'American, burger, Fast Food', 'American, BBQ, Southern, Comf ...
# Cluster 2: ['American, Mexican, Snacks', 'Pizza, Comfort Food, Vegetarian', 'Seafood, American, Southern, Healthy, Desserts', 'American, Sandwich, Hot Dog, Allergy Friendly', 'American, Comfort Food, Fried Chicken, Family Meals, Sandwich, Family Friendly', 'Pasta, Italian, American, Fast Food, Vegetarian Friendly', 'American, Wings, Fast Food, Chicken', 'American, Chicken, Wings', 'American, Wings, Chicken', 'American, Burgers, Sandwiches', 'Indian, Pakistani, Vegetarian, Halal, Chicken', 'American, Chicken Strips, Wings, Chicken', 'American, Breakfast and Brunch, Coffee and Tea, Dinner, Desserts, Salads, Steak, Sandwich, Family Meals, Healthy']
# Cluster 3: ['American, Sandwiches, Desserts', 'American, burger, Fast Food, Family Meals', 'Burgers, American, Sandwiches', 'Bar Food, American, Traditional American, Family Meals', 'Salads, Pizza, Desserts, Healthy', 'Asian, Indian, Comfort Food, Pakistani, Chicken, Halal, Vegetarian, Fast Food', 'Italian, Pizza, Pasta, Exclusive to Eats, Salads, Sandwiches', 'Pizza, American, Italian, Wings, Pasta, Family Meals', 'Mexican, Latin American, New Mexican', 'Italian, Salads, Pasta, Healthy', 'American, Comfort Food', 'BBQ, American, Comfort Food, Family Meals', 'American, burger, Fast Food', 'American, burger, Fast Food, Family Meals', 'Seafood, Desserts, Kids Friendly', 'Chicken, Seafood, Salads, Healthy, Allergy Friendly', 'Italian, Pizza, Pasta, Family Friendly', 'Asian, Asian Fusion, Rice-bowls, Vegetarian Friendly, Chinese', 'Latin American, Mexican, New American, Family Meals, Family Friendly', 'Italian, Pasta, Alcohol', 'Italian, Pasta, Alcohol', 'American, Wings, Chicken', 'American, Sandwiches, Vegetarian', 'Pizza, Wings, Italian, Salads, Family Meals', 'BBQ, Wings, Family Meals', 'Chinese: Other, Chinese, Asian', 'American, Chicken, Family Meals, Fried Chicken, Comfort Food', 'Burritos, Fast Food, Mexican', 'Caribbean, Seafood, Latin American, Soul Food', 'American, Burgers, Comfort Food', 'American, burger, Fast Food', 'American, Comfort Food, Fried Chicken, Family Meals, Sandwich, Family Friendly', 'Burgers, American, Sandwiches, Desserts', 'Sandwiches, American, Cheese', 'Mexican, Tex Mex, Breakfast and Brunch, Family Meals', 'Fast Food, Family Meals', 'Indian Curry, Indian, Pakistani, Healthy, Vegan', 'American, Chicken, Family Meals, Fried Chicken, Comfort Food', 'Burgers, Pizza, Salads, Family Meals, Healthy', 'American, BBQ, Comfort Food', 'Burgers, Fast Food, Burgers, Sandwiches, American', 'American, Fast Food, Burgers', 'Seafood, American, Family Meals', 'American, Burgers, Comfort Food, Vegetarian Friendly, Fast Food', 'American, burger, Fast Food, Family Meals']
# Cluster 4: ['American, Burgers, Family Friendly, Wings, Alcohol', 'Burgers, American, Sandwiches, Family Meals', 'American, Burgers, Salads, Healthy, Family Friendly, Comfort Food, Pasta, Sandwiches, Steak, Wings', 'BBQ, American', 'American, Sushi', 'BBQ, American', 'Italian, pizza, Comfort Food, Family Friendly', 'Seafood, Mexican, Tacos, South American, Healthy', 'Mexican, Latin American, New Mexican, Fast Food, Family Meals, Group Friendly', 'Burgers, American, Sandwiches', 'American, Burgers, Fast Food', 'American, Bar Food, Wings, Fast Food, Chicken, Family Meals, Exclusive to Eats, Comfort Food', 'Family Meals', 'Burgers, Fast Food, Burgers, Sandwiches, American', 'Pizza, Salads, Wings, Family Meals, Healthy', 'American, Fast Food, Sandwich', 'Healthy, Mexican', 'Desserts', 'Mexican, Tex Mex, Breakfast and Brunch, Family Meals', 'Mexican, Breakfast and Brunch', 'Mexican, Burritos, Tacos, Quesadillas', 'Pizza, Wings, Sandwiches, Desserts, American, Traditional American, Fast Food', 'Breakfast and Brunch, Mexican', 'Sandwich, Deli, Salads, Healthy', 'Healthy, Gluten Free, Breakfast and Brunch', 'Burgers', 'Burgers, American, Fast Food, Chicken', 'Bakery, Comfort Food, American', 'Asian', 'Noodles, Asian Fusion, Japanese, Ramen', 'Steak, American, Seafood', 'Mexican, New Mexican, Salads, Exclusive to Eats', 'Vietnamese, Noodles, Healthy, Asian, Bubble Tea, Family Meals', 'Asian, Desserts', 'Asian, Indian, Comfort Food', 'Mexican', 'Italian, Pasta, Comfort Food', 'Asian, Indian, Comfort Food', 'Italian', 'Mexican, Latin American, New Mexican, Breakfast and Brunch, Chicken, Asado, Steak, Soup, Burritos, Tacos, Tex Mex, American', 'Italian, Pasta, Comfort Food', 'Greek, Mediterranean', 'Italian, Family Meals, Salads', 'Italian, Pizza, Pasta', 'Chinese, Asian, Asian Fusion', 'Asian, Chinese, Family Meals', 'Pizza, Pasta, Breakfast and Brunch', 'Seafood, American, Southern, Healthy, Desserts, Alcohol', 'Chinese, Asian, Asian-owned, Noodles, Rice Dishes', 'Japanese, Sushi, Rolls', 'Mexican, Latin American, New Mexican', 'American, Burgers, Comfort Food, Vegetarian Friendly, Fast Food', 'Mexican, Latin American, New Mexican, Tacos, Tex Mex, Hot Dog, Burgers', 'Mexican, Soup, Breakfast and Brunch, Latin American, New Mexican, Asado, Steak, Chicken, Soup, Burritos, Tacos, Tex Mex, American', 'American, Pizza', 'Mexican, Latin American, New Mexican', 'Mexican, New Mexican, Latin American, Tex Mex, Local Specialities', 'Pizza, American, Italian, Wings', 'Mexican, Latin American, New Mexican', 'Burgers, American, Sandwiches', 'Mexican, American', 'Burgers, American, Sandwiches, Seafood, Bar Food, Cafe, Wings', 'Mexican, Latin American, New Mexican', 'Mexican, Latin American', 'Burgers, American, Sandwiches, BBQ, Family Meals', 'American, Sandwich', 'Mexican, Latin American, New Mexican, Tacos, Breakfast and Brunch', 'American, Seafood', 'Pizza, American, Italian', 'Fast Food, Wings, American, Family Meals', 'American, Chicken, Comfort Food', 'Fast Food, American, Family Meals, Family Friendly', 'Seafood, American, Family Meals, Fish and Chips, Chicken', 'Burgers, Sandwich, American, Fast Food, burger, Hot Dog, American, Sandwiches', 'Chinese, Asian, Asian Fusion, Kids Friendly, Local Specialities', 'Mexican, Burgers, Kids Friendly', 'Burgers, American, Vegetarian Friendly', 'Vietnamese, Noodles, Healthy, Vegetarian, Vegetarian Friendly, Thai, Rice Dishes, Chinese, Pho', 'Pizza, American, Italian, Allergy Friendly', 'Mexican, Latin American, New Mexican, Group Friendly', 'Asian, Asian Fusion, Korean', 'Desserts, chocolatier, Pastry, Cupcakes, Gluten Free Friendly', 'Chinese, Seafood, Noodles, Chicken, Vegetarian Friendly, Family Friendly, Allergy Friendly, Sushi, Japanese', 'Seafood, American, Southern, Family Friendly', 'Italian, pizza, Salads, Healthy, Family Friendly', 'American, Sandwich, Family Friendly', 'Chinese, Asian, Asian Fusion, Vegetarian, Vegetarian Friendly, Noodles, Rice Dishes, Kids Friendly, Soup', 'Italian, Desserts, ...

# %%
restaurants_df_cleaned.dtypes
# Out:
# id               int64
# position         int64
# name            object
# score          float64
# ratings        float64
# category        object
# price_range     object
# lat            float64
# lng            float64
# address         object
# city            object
# state           object
# zip_code       float64
# cluster          int32
# dtype: object

# %%
#Find out 'What are the highest scored food categories in Cluster 0: Top Shelf (4.7-5.0)?'
import matplotlib.pyplot as plt
# Assuming 'cluster_zero' is your DataFrame
filtered_df = cluster_zero[cluster_zero['cluster'] == 0]  # Filter rows where cluster is 0
category_counts = filtered_df['category'].value_counts()

#filter to top ten categories
top_ten = category_counts.head(10)

# Create a larger figure to accommodate x tick labels
fig, ax = plt.subplots(figsize=(10, 12))

# Plotting the bar graph
plt.bar(top_ten.index, top_ten.values, color='#FF8674')
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Bar Graph of Category for Top Shelf (4.7-5.0)')
plt.xticks(rotation=90, ha="right")  # Rotate category labels for better visibility

# Display the plot
plt.show()

# %%
#cleaning up zi_code column
#convert 'zip_code' to integer
cluster_zero['zip_code']=cluster_zero['zip_code'].astype(int)
restaurants_df_cleaned['zip_code']=restaurants_df_cleaned['zip_code'].astype(int)
# Out:
# C:\Users\muell\AppData\Local\Temp\ipykernel_17536\4254568136.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cluster_zero['zip_code']=cluster_zero['zip_code'].astype(int)
# C:\Users\muell\AppData\Local\Temp\ipykernel_17536\4254568136.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   restaurants_df_cleaned['zip_code']=restaurants_df_cleaned['zip_code'].astype(int)

# %%
#Find out 'What zip code should you stay in San Antonio to be close to delectable food?''
import seaborn as sns

# Assuming 'cluster_zero' is your DataFrame
filtered_df = cluster_zero[cluster_zero['cluster'] == 0]
# Count occurrences of each zipcode in cluster 0
zipcode_counts = filtered_df['zip_code'].value_counts()
# Create the bar graph
plt.figure(figsize=(12, 8))
sns.barplot(x=zipcode_counts.index, y=zipcode_counts.values)
plt.xlabel('Zipcode')
plt.ylabel('Number of Restaurants')
plt.title('Counts of Restaurants in Zipcodes from the Top Shelf Cluster')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# List of keywords to check for in the 'category' column
keywords = ['Mexican', 'Latin American', 'New Mexican']
# Filter the DataFrame based on the 'category' column
mexican_data = restaurants_df_cleaned[restaurants_df_cleaned['category'].str.contains('|'.join(keywords), case=False)]

# Plot a bar graph using seaborn
plt.figure(figsize=(10, 6))  # Set the figure size
sns.countplot(data=mexican_data, x='zip_code')

# Adding labels and title
plt.xlabel('Zip Codes')
plt.ylabel('Count')
plt.title('Bar Graph of Mexican Category by Zip Codes')

# Rotate x-axis labels for better visibility if needed
plt.xticks(rotation=45)

# Display the plot
plt.tight_layout()
plt.show()

# %%
#Saving the file
restaurants_df_cleaned.to_csv("Output/restaurants_clustered.csv", index=False, header=True)
